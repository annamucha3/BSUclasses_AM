# %% [markdown]
# <a href="https://colab.research.google.com/github/annamucha3/BSUclasses_AM/blob/main/DSA601_Hospital_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="blue"> Team: Anna Mucha, Navya Mehta, and Vipul Arora
#
#
# <font color="blue"> This is a project for DSA-601.
#
# <font color="blue">This project is intended to predict the length of stay and costs at hospitals in Western New York by using machine learning models.
#
# <font color="blue">The dataset comes directly from the New York Department of Health. There is no PHI due to HIPAA, and no individual is identifiable. The dataset contains basic patient record level details. We have filtered the dataset down to only include Western New York. This covers the 8 counties which are Erie, Chautauqua, Wyoming, Cattaraugus, Niagara, Allegany, Genesee, and Orleans.

# %% [markdown]
# <font color="blue">To help us understand some of the data points from looking at the data dictonary provied by the Health Department with the dataset.
#
# 1. Zip Code - Only has the first 3 digits of the patients zip code. (we Might want to only look at the Hospital County rather than the 3 digit zip as it does not give us the exact location)
# OOP stands for "out of state" zip codes.
#
# 2. Patient Disposition - The destination or status when the patient is leaving the facility (discharge)
#
# 3. CCSR Diagnosis Code - This is the Clinical Classification Software Refined for ICD-10CM (diagnosis codes, meaning what the patient was diagnosed with).This aggregates the more than 70,000 ICD-10CM diagnosis codes into over 520 clinically meaningful categories.
#
# 4. CCSR Procedure Code - AHRQ (Agency for Healthcare Research and Quality) Clinical Classification Software Refined ICD-10 procedure code category (codes to identify what was done or given to the patient, such as surgeries, medical equitment, or medications.
#
# 5. APR DRG Code - All Patients Refined Diagnosis Related Groups. This is a classification system that classidies patients according to their reason for admission (why did they come to the hospital). This is a more specific classification.
#
# 6. APR MDC Code - Similar to the DRG code but is a higher level classification on the primary diagnosis.
#
# 7. APR Severity of Illness Code - All Patient Refined severity of illness code 0-4, indicating respectively, (1) minor, (2) moderate, (3) major, or (4)extreme severity of illness.
#
# 8. APR Risk of Mortality - All Patient Refined isk of mortality also called (APR ROM). These are indicated as Undetermined (0), Minor (1), Moderate (2), Major (3), Extreme (4).
#
# 9. Payment Typology 1 - Payment type (or insurance used) for payment for the occurence.
#
# 10. Payment Typology 2 - Payment type (or insurance used) for payment for the occurence.
#
# 11. Payment Typology 3 - Payment type (or insurance used) for payment for the occurence.
#
# 12. Birth Weight - Neonate birth weight in grams. Rounded to the nearest 100g.
#
# * Might want to remove this field all together, as there are nulls and might not be extremely important for this.
#
# 13. Emergency Department Indicator - This is based on the submitted revenue codes from the hospital. If the record contained an Emergeny Department revenue code of 045X, the indicator is "Y", otherwise it will be "N".
#
# 14. Total Charges - Total charges for the discharge.
#
# 15. Total Costs - Total estimated cost for the discharge. This takes into consideration the payment typology or the insurance.
#
# 16. Length of Stay - Total number of days patient at an acute level and/0r other than acute care level. (discharge data - admission date) + 1. Length of stay greater than or equal to 120 days is written as 120+ day.
#
#
# </font>

# %%
#API Endpoint
#but only lets you take 1,000 rows. Instead I'll bring in as a csv to get all of the data.
#https://health.data.ny.gov/resource/yjgt-tq93.json?$query=SELECT%0A%20%20%60hospital_service_area%60%2C%0A%20%20%60hospital_county%60%2C%0A%20%20%60operating_certificate_number%60%2C%0A%20%20%60permanent_facility_id%60%2C%0A%20%20%60facility_name%60%2C%0A%20%20%60age_group%60%2C%0A%20%20%60zip_code_3_digits%60%2C%0A%20%20%60gender%60%2C%0A%20%20%60race%60%2C%0A%20%20%60ethnicity%60%2C%0A%20%20%60length_of_stay%60%2C%0A%20%20%60type_of_admission%60%2C%0A%20%20%60patient_disposition%60%2C%0A%20%20%60discharge_year%60%2C%0A%20%20%60ccsr_diagnosis_code%60%2C%0A%20%20%60ccsr_diagnosis_description%60%2C%0A%20%20%60ccsr_procedure_code%60%2C%0A%20%20%60ccsr_procedure_description%60%2C%0A%20%20%60apr_drg_code%60%2C%0A%20%20%60apr_drg_description%60%2C%0A%20%20%60apr_mdc_code%60%2C%0A%20%20%60apr_mdc_description%60%2C%0A%20%20%60apr_severity_of_illness_code%60%2C%0A%20%20%60apr_severity_of_illness%60%2C%0A%20%20%60apr_risk_of_mortality%60%2C%0A%20%20%60apr_medical_surgical%60%2C%0A%20%20%60payment_typology_1%60%2C%0A%20%20%60payment_typology_2%60%2C%0A%20%20%60payment_typology_3%60%2C%0A%20%20%60birth_weight%60%2C%0A%20%20%60emergency_department_indicator%60%2C%0A%20%20%60total_charges%60%2C%0A%20%20%60total_costs%60%0AWHERE%20caseless_one_of(%60hospital_service_area%60%2C%20%22Western%20NY%22)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

csv_path = "/content/Hospital_Inpatient_Discharges__SPARCS_De-Identified___2018_20240315.csv"

df = pd.read_csv(csv_path)
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
# <ipython-input-7-c62a143cff06>:5: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0            Western NY            Erie                       1401014
# 1            Western NY            Erie                       1401014
# 2            Western NY            Erie                       1401014
# 3            Western NY            Erie                       1401014
# 4            Western NY            Erie                       1401014
#
#    Permanent Facility Id                   Facility Name    Age Group  \
# 0                    207  Buffalo General Medical Center  70 or Older
# 1                    207  Buffalo General Medical Center     50 to 69
# 2                    207  Buffalo General Medical Center  70 or Older
# 3                    207  Buffalo General Medical Center     50 to 69
# 4                    207  Buffalo General Medical Center     30 to 49
#
#   Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 0                 142      F                   White  Not Span/Hispanic
# 1                 141      M              Other Race            Unknown
# 2                 147      M                   White  Not Span/Hispanic
# 3                 142      F  Black/African American  Not Span/Hispanic
# 4                 147      M                   White  Not Span/Hispanic
#
#   Length of Stay Type of Admission                Patient Disposition  \
# 0              8         Emergency  Inpatient Rehabilitation Facility
# 1              2            Urgent       Home w/ Home Health Services
# 2              1          Elective                  Home or Self Care
# 3              6         Emergency                  Home or Self Care
# 4              1         Emergency                  Home or Self Care
#
#    Discharge Year CCSR Diagnosis Code  \
# 0            2018              INJ037
# 1            2018              INJ006
# 2            2018              CIR023
# 3            2018              DIG013
# 4            2018              END012
#
#                           CCSR Diagnosis Description CCSR Procedure Code  \
# 0  COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE...              MST020
# 1  FRACTURE OF THE NECK OF THE FEMUR (HIP), INITI...              MST007
# 2  OCCLUSION OR STENOSIS OF PRECEREBRAL OR CEREBR...              CAR006
# 3                  DIVERTICULOSIS AND DIVERTICULITIS              GIS002
# 4                                    CYSTIC FIBROSIS                 NaN
#
#                 CCSR Procedure Description  APR DRG Code  \
# 0  SUBCUTANEOUS TISSUE AND FASCIA EXCISION           721
# 1                         HIP ARTHROPLASTY           301
# 2      CAROTID ENDARTERECTOMY AND STENTING            24
# 3  COLONOSCOPY AND PROCTOSCOPY WITH BIOPSY           244
# 4                                      NaN           254
#
#                                  APR DRG Description  APR MDC Code  \
# 0  POST-OPERATIVE, POST-TRAUMATIC, OTHER DEVICE I...            18
# 1                              HIP JOINT REPLACEMENT             8
# 2                   EXTRACRANIAL VASCULAR PROCEDURES             1
# 3                    DIVERTICULITIS & DIVERTICULOSIS             6
# 4                   OTHER DIGESTIVE SYSTEM DIAGNOSES             6
#
#                                  APR MDC Description  \
# 0  INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR...
# 1  DISEASES AND DISORDERS OF THE MUSCULOSKELETAL ...
# 2       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM
# 3     DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM
# 4     DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             4                             Extreme
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             3                               Major
# 4                             2                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0               Extreme                          Medical
# 1                 Minor                         Surgical
# 2                 Minor                         Surgical
# 3              Moderate                          Medical
# 4                 Minor                          Medical
#
#          Payment Typology 1        Payment Typology 2 Payment Typology 3  \
# 0                  Medicare    Blue Cross/Blue Shield           Self-Pay
# 1       Miscellaneous/Other  Private Health Insurance           Self-Pay
# 2                  Medicare                  Self-Pay                NaN
# 3                  Medicare                  Self-Pay           Self-Pay
# 4  Private Health Insurance                  Self-Pay                NaN
#
#   Birth Weight  Emergency Department Indicator  Total Charges  Total Costs
# 0          NaN                            True       55367.55     20121.21
# 1          NaN                           False       48328.30     16943.32
# 2          NaN                           False       17052.12      7673.72
# 3          NaN                            True       17287.12      9058.50
# 4          NaN                            True        6821.06      1987.18

# %%
df.dtypes
# Out:
# Hospital Service Area                   object
# Hospital County                         object
# Operating Certificate Number             int64
# Permanent Facility Id                    int64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCSR Diagnosis Code                     object
# CCSR Diagnosis Description              object
# CCSR Procedure Code                     object
# CCSR Procedure Description              object
# APR DRG Code                             int64
# APR DRG Description                     object
# APR MDC Code                             int64
# APR MDC Description                     object
# APR Severity of Illness Code             int64
# APR Severity of Illness Description     object
# APR Risk of Mortality                   object
# APR Medical Surgical Description        object
# Payment Typology 1                      object
# Payment Typology 2                      object
# Payment Typology 3                      object
# Birth Weight                            object
# Emergency Department Indicator            bool
# Total Charges                          float64
# Total Costs                            float64
# dtype: object

# %%
df.rename(columns={'Zip Code - 3 digits': 'Short Zip Code'}, inplace=True)

# %%
null_count = df.isnull().sum()
total_rows = len(df)
null_percentage = (null_count / total_rows) * 100
all_nulls = pd.DataFrame({'Null Count': null_count, 'Null Percentage': null_percentage})

all_nulls
# Out:
#                                      Null Count  Null Percentage
# Hospital Service Area                         0         0.000000
# Hospital County                               0         0.000000
# Operating Certificate Number                  0         0.000000
# Permanent Facility Id                         0         0.000000
# Facility Name                                 0         0.000000
# Age Group                                     0         0.000000
# Short Zip Code                             1411         0.842172
# Gender                                        0         0.000000
# Race                                          0         0.000000
# Ethnicity                                     0         0.000000
# Length of Stay                                0         0.000000
# Type of Admission                             0         0.000000
# Patient Disposition                           0         0.000000
# Discharge Year                                0         0.000000
# CCSR Diagnosis Code                           2         0.001194
# CCSR Diagnosis Description                    2         0.001194
# CCSR Procedure Code                       63470        37.882812
# CCSR Procedure Description                63470        37.882812
# APR DRG Code                                  0         0.000000
# APR DRG Description                           0         0.000000
# APR MDC Code                                  0         0.000000
# APR MDC Description                           0         0.000000
# APR Severity of Illness Code                  0         0.000000
# APR Severity of Illness Description           8         0.004775
# APR Risk of Mortality                         8         0.004775
# APR Medical Surgical Description              0         0.000000
# Payment Typology 1                            0         0.000000
# Payment Typology 2                        44939        26.822368
# Payment Typology 3                       138224        82.500612
# Birth Weight                             152161        90.819073
# Emergency Department Indicator                0         0.000000
# Total Charges                                 0         0.000000
# Total Costs                                   0         0.000000

# %%
null_zip_code = df[df['Short Zip Code'].isnull()]
null_zip_code
# Out:
#        Hospital Service Area Hospital County  Operating Certificate Number  \
# 78                Western NY            Erie                       1401013
# 102               Western NY            Erie                       1401005
# 129               Western NY            Erie                       1401013
# 356               Western NY      Chautauqua                        601000
# 357               Western NY      Chautauqua                        601000
# ...                      ...             ...                           ...
# 167225            Western NY         Niagara                       3121001
# 167397            Western NY         Niagara                       3121001
# 167412            Western NY         Niagara                       3121001
# 167422            Western NY         Niagara                       3121001
# 167476            Western NY         Niagara                       3121001
#
#         Permanent Facility Id                                Facility Name  \
# 78                        218                  Sisters of Charity Hospital
# 102                       210                   Erie County Medical Center
# 129                       218                  Sisters of Charity Hospital
# 356                        98             Brooks-TLC Hospital System, Inc.
# 357                        98             Brooks-TLC Hospital System, Inc.
# ...                       ...                                          ...
# 167225                    583  Mount St. Mary's Hospital and Health Center
# 167397                    583  Mount St. Mary's Hospital and Health Center
# 167412                    583  Mount St. Mary's Hospital and Health Center
# 167422                    583  Mount St. Mary's Hospital and Health Center
# 167476                    583  Mount St. Mary's Hospital and Health Center
#
#        Age Group Short Zip Code Gender                    Race  \
# 78      30 to 49            NaN      F                   White
# 102      0 to 17            NaN      M                   White
# 129     18 to 29            NaN      F              Other Race
# 356     18 to 29            NaN      F              Other Race
# 357      0 to 17            NaN      M              Other Race
# ...          ...            ...    ...                     ...
# 167225   0 to 17            NaN      M              Other Race
# 167397   0 to 17            NaN      F              Other Race
# 167412   0 to 17            NaN      F  Black/African American
# 167422   0 to 17            NaN      M              Other Race
# 167476   0 to 17            NaN      F              Other Race
#
#                 Ethnicity Length of Stay Type of Admission  \
# 78      Not Span/Hispanic             42         Emergency
# 102               Unknown              4          Elective
# 129      Spanish/Hispanic              4         Emergency
# 356      Spanish/Hispanic              4          Elective
# 357      Spanish/Hispanic              3           Newborn
# ...                   ...            ...               ...
# 167225  Not Span/Hispanic              2           Newborn
# 167397  Not Span/Hispanic              2           Newborn
# 167412  Not Span/Hispanic              2           Newborn
# 167422  Not Span/Hispanic              1           Newborn
# 167476  Not Span/Hispanic              1           Newborn
#
#         Patient Disposition  Discharge Year CCSR Diagnosis Code  \
# 78        Home or Self Care            2018              MUS002
# 102       Home or Self Care            2018              MBD002
# 129       Home or Self Care            2018              MUS026
# 356       Home or Self Care            2018              PRG026
# 357       Home or Self Care            2018              PNL001
# ...                     ...             ...                 ...
# 167225    Home or Self Care            2018              PNL001
# 167397    Home or Self Care            2018              PNL001
# 167412    Home or Self Care            2018              PNL001
# 167422  Short-term Hospital            2018              PNL001
# 167476    Home or Self Care            2018              PNL001
#
#                      CCSR Diagnosis Description CCSR Procedure Code  \
# 78                                OSTEOMYELITIS              CAR024
# 102                        DEPRESSIVE DISORDERS                 NaN
# 129                            MUSCLE DISORDERS                 NaN
# 356     OB-RELATED TRAUMA TO PERINEUM AND VULVA              PGN002
# 357                                    LIVEBORN                 NaN
# ...                                         ...                 ...
# 167225                                 LIVEBORN                 NaN
# 167397                                 LIVEBORN                 NaN
# 167412                                 LIVEBORN                 NaN
# 167422                                 LIVEBORN                 NaN
# 167476                                 LIVEBORN                 NaN
#
#                     CCSR Procedure Description  APR DRG Code  \
# 78      VENOUS AND ARTERIAL CATHETER PLACEMENT           892
# 102                                        NaN           754
# 129                                        NaN           351
# 356               SPONTANEOUS VAGINAL DELIVERY           542
# 357                                        NaN           640
# ...                                        ...           ...
# 167225                                     NaN           640
# 167397                                     NaN           640
# 167412                                     NaN           640
# 167422                                     NaN           581
# 167476                                     NaN           640
#
#                                       APR DRG Description  APR MDC Code  \
# 78                      HIV W MAJOR HIV RELATED CONDITION            24
# 102           DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER            19
# 129     OTHER MUSCULOSKELETAL SYSTEM & CONNECTIVE TISS...             8
# 356     VAGINAL DELIVERY W COMPLICATING PROCEDURES EXC...            14
# 357     NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR NEON...            15
# ...                                                   ...           ...
# 167225  NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR NEON...            15
# 167397  NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR NEON...            15
# 167412  NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR NEON...            15
# 167422       NEONATE, TRANSFERRED < 5 DAYS OLD, BORN HERE            15
# 167476  NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR NEON...            15
#
#                                       APR MDC Description  \
# 78                HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS
# 102                         MENTAL DISEASES AND DISORDERS
# 129     DISEASES AND DISORDERS OF THE MUSCULOSKELETAL ...
# 356              PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 357     NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# ...                                                   ...
# 167225  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 167397  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 167412  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 167422  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 167476  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
#
#         APR Severity of Illness Code APR Severity of Illness Description  \
# 78                                 3                               Major
# 102                                2                            Moderate
# 129                                2                            Moderate
# 356                                1                               Minor
# 357                                1                               Minor
# ...                              ...                                 ...
# 167225                             1                               Minor
# 167397                             1                               Minor
# 167412                             1                               Minor
# 167422                             1                               Minor
# 167476                             1                               Minor
#
#        APR Risk of Mortality APR Medical Surgical Description  \
# 78                     Minor                          Medical
# 102                    Minor                          Medical
# 129                    Minor                          Medical
# 356                    Minor                         Surgical
# 357                    Minor                          Medical
# ...                      ...                              ...
# 167225                 Minor                          Medical
# 167397                 Minor                          Medical
# 167412                 Minor                          Medical
# 167422                 Minor                          Medical
# 167476                 Minor                          Medical
#
#               Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# 78                      Medicaid           Medicaid                NaN
# 102                     Medicaid           Medicaid                NaN
# 129     Private Health Insurance                NaN                NaN
# 356                     Medicaid                NaN                NaN
# 357                     Medicaid                NaN                NaN
# ...                          ...                ...                ...
# 167225  Private Health Insurance                NaN                NaN
# 167397  Private Health Insurance                NaN                NaN
# 167412  Private Health Insurance                NaN                NaN
# 167422  Private Health Insurance                NaN                NaN
# 167476  Private Health Insurance                NaN                NaN
#
#        Birth Weight  Emergency Department Indicator  Total Charges  \
# 78              NaN                            True      120916.08
# 102             NaN                           False        6045.36
# 129             NaN                            True       12777.59
# 356             NaN                           False       15871.70
# 357           03100                           False        5649.60
# ...             ...                             ...            ...
# 167225        02700                           False        2374.56
# 167397        03600                           False        2422.06
# 167412        03000                           False        2445.92
# 167422        02300                           False        1620.76
# 167476        03700                           False        1345.92
#
#         Total Costs
# 78         59322.59
# 102         3932.67
# 129         5619.82
# 356        14621.61
# 357         2260.12
# ...             ...
# 167225      3842.32
# 167397      3839.17
# 167412      3876.63
# 167422      2103.73
# 167476      2036.70
#
# [1411 rows x 33 columns]

# %%
unique_zip = df['Short Zip Code'].unique()
unique_zip.tolist()
# Out:
# ['142',
#  '141',
#  '147',
#  '140',
#  '143',
#  'OOS',
#  nan,
#  '144',
#  '145',
#  '148',
#  '146',
#  '105',
#  '119',
#  '134',
#  '136',
#  '131',
#  '132',
#  '138',
#  '117',
#  '130',
#  '104',
#  '133',
#  '149',
#  '109',
#  '120',
#  '137',
#  '139',
#  '100',
#  '121',
#  '110',
#  '108',
#  '135',
#  '112']

# %%
test = df[['Short Zip Code', 'Hospital County']].drop_duplicates()
test
# Out:
#        Short Zip Code Hospital County
# 0                 142            Erie
# 1                 141            Erie
# 2                 147            Erie
# 9                 140            Erie
# 25                143            Erie
# ...               ...             ...
# 103703            140        Allegany
# 149686            100            Erie
# 158692            117         Wyoming
# 158774            146         Wyoming
# 159195            145        Allegany
#
# [103 rows x 2 columns]

# %% [markdown]
# <font color="red">After doing some reserch on the 3 digit zip codes. One 3 digit zip code can correspond to several counties. Therefore we might want to not look at zip all together..

# %%
# Dropping the 3rd payment typology since the 1st one seems to be a primary?

# Most nulls in the 3rd payment typology column.
df.drop(columns=['Payment Typology 3'], inplace=True)

# %%
# wont be necessay for our modeling
df.drop(columns=['Operating Certificate Number'], inplace=True)

# %%
# wont be necessay for our modeling
df.drop(columns=['Permanent Facility Id'], inplace=True)

# %%
# 90% nulls in this column
df.drop(columns=['Birth Weight'], inplace=True)

# %%
unique_MDC = df['APR MDC Description'].unique()
unique_MDC.tolist()
# Out:
# ['INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)',
#  'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE',
#  'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM',
#  'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM',
#  'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM',
#  'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM',
#  'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
#  'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD',
#  'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT',
#  'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS',
#  'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST',
#  'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM',
#  'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS',
#  'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS',
#  'MENTAL DISEASES AND DISORDERS',
#  'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS',
#  'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT',
#  'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM',
#  'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS',
#  'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM',
#  'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS',
#  'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES',
#  'DISEASES AND DISORDERS OF THE EYE',
#  'MULTIPLE SIGNIFICANT TRAUMA',
#  'PRE MDC',
#  'BURNS']

# %% [markdown]
# <font color="lightblue"> I want to shorten the description names. This will be useful when we do one hot encoding. Since this is the more general classification I will do it on MDC. DRG has many more values and wont be able to generalize as easily.

# %%
mdc = {'APR MDC Description': ['INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)' ,
 'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE',
 'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM',
 'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM',
 'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM',
 'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM',
 'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM',
 'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD',
 'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT',
 'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS',
 'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST',
 'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM',
 'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS',
 'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS',
 'MENTAL DISEASES AND DISORDERS',
 'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS',
 'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT',
 'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM',
 'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS',
 'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM',
 'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS',
 'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES',
 'DISEASES AND DISORDERS OF THE EYE',
 'MULTIPLE SIGNIFICANT TRAUMA',
 'PRE MDC',
 'BURNS']
 }

# %%
mdc_description_mapping = {

    'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)' : 'Infectious Diseases',
    'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE' : 'Musculoskeletal System',
    'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM' : 'Nervous System',
    'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM' : 'Digestive System',
    'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM' : 'Circulatory System',
    'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM' : 'Respiratory System',
    'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM' : 'Maternal Health',
    'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD' : 'Neonatal Disorders',
    'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT' : 'Renal and Urinary Disorders',
    'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS' : 'Metabolic Disorders',
    'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST' : 'Skin and Breast Disorders',
    'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM' : 'Gynecological Disorders',
    'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS' : 'Viral Infections',
    'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS' : 'Hepatopancreatic Conditions',
    'MENTAL DISEASES AND DISORDERS' : 'Mental Disorders',
    'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS' : 'Substance-induced Disorders',
    'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT' : 'ENT Disorders',
    'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM' : 'Myeloproliferative Diseases ',
    'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS' : 'Hematological and Immunological Disorders',
    'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM' : 'Male Reproductive Disorders',
    'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS' : 'Injury and Drug Toxicity',
    'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES' : 'Healthcare Utilization Factors',
    'DISEASES AND DISORDERS OF THE EYE' : 'Eye Disorders',
    'MULTIPLE SIGNIFICANT TRAUMA' : 'Trauma',
    'PRE MDC' : 'Pre MDC',
    'BURNS' : 'Burns',
}

df['General_MDC'] = df['APR MDC Description'].map(mdc_description_mapping)

# %% [markdown]
# <font color="red"> Can remove the APR MDC Description column in the future since we created a general MDC to shorten the description.

# %% [markdown]
# <font color="lightblue"> Payment Typology 2	has about 27% nulls. I am going to impute the nulls with the Payment Typology 1.

# %%
df['Payment Typology 2'].fillna(df['Payment Typology 1'], inplace=True)

# %% [markdown]
# <font color="lightblue"> There are only 8 columns (less than 1%) in the APR Risk of Mortality column. So I am going to drop these rows.

# %%
df.dropna(subset=['APR Risk of Mortality'], inplace=True)

# %% [markdown]
# <font color="lightblue"> Adding on 3/27

# %%
df = df[df['Gender'] != 'U']

# %%
unique_g = df['Gender'].unique()
unique_g
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.drop('Hospital Service Area', axis=1, inplace=True)
# Out:
# <ipython-input-25-3d6f2f35e78d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Hospital Service Area', axis=1, inplace=True)

# %%
unique_f = df['Facility Name'].unique().tolist()
unique_f
# Out:
# ['Buffalo General Medical Center',
#  "John R. Oishei Children's Hospital",
#  'Millard Fillmore Suburban Hospital',
#  'UPMC Chautauqua at WCA',
#  'Sisters of Charity Hospital',
#  'Wyoming County Community Hospital',
#  'Erie County Medical Center',
#  'Mercy Hospital of Buffalo',
#  'Olean General Hospital',
#  'Kenmore Mercy Hospital',
#  'Brooks-TLC Hospital System, Inc.',
#  "Mount St. Mary's Hospital and Health Center",
#  'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp',
#  'Eastern Niagara Hospital - Lockport Division',
#  'Roswell Park Cancer Institute',
#  'United Memorial Medical Center North Street Campus',
#  'Niagara Falls Memorial Medical Center',
#  'Sisters of Charity Hospital - St. Joseph Campus',
#  'Bertrand Chaffee Hospital',
#  'Cuba Memorial Hospital Inc',
#  'Degraff Memorial Hospital',
#  'United Memorial Medical Center Bank Street Campus',
#  'Medina Memorial Hospital',
#  'Westfield Memorial Hospital Inc']

# %% [markdown]
# <font color="lightblue"> I wanted to shorten the names for our analysis, but once we present we will use the full names for the hositals rather than the shortened names.

# %%
hospitals = {
    'Facility Name':[
        'Buffalo General Medical Center',
        "John R. Oishei Children's Hospital",
        'Millard Fillmore Suburban Hospital',
        'UPMC Chautauqua at WCA',
        'Sisters of Charity Hospital',
        'Wyoming County Community Hospital',
        'Erie County Medical Center',
        'Mercy Hospital of Buffalo',
        'Olean General Hospital',
        'Kenmore Mercy Hospital',
        'Brooks-TLC Hospital System, Inc.',
        "Mount St. Mary's Hospital and Health Center",
        'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp',
        'Eastern Niagara Hospital - Lockport Division',
        'Roswell Park Cancer Institute',
        'United Memorial Medical Center North Street Campus',
        'Niagara Falls Memorial Medical Center',
        'Sisters of Charity Hospital - St. Joseph Campus',
        'Bertrand Chaffee Hospital',
        'Cuba Memorial Hospital Inc',
        'Degraff Memorial Hospital',
        'United Memorial Medical Center Bank Street Campus',
        'Medina Memorial Hospital',
        'Westfield Memorial Hospital Inc']
}

# %%
hospitals_mapping = {
        'Buffalo General Medical Center': 'Buffalo General',
        "John R. Oishei Children's Hospital": "Oishei Children's",
        'Millard Fillmore Suburban Hospital': 'Suburban',
        'UPMC Chautauqua at WCA': 'UPMC',
        'Sisters of Charity Hospital': 'Sisters',
        'Wyoming County Community Hospital': 'WCCHS',
        'Erie County Medical Center': 'ECMC',
        'Mercy Hospital of Buffalo': 'Mercy',
        'Olean General Hospital': 'Olean General',
        'Kenmore Mercy Hospital': 'Kenmore Mercy',
        'Brooks-TLC Hospital System, Inc.': 'Brooks',
        "Mount St. Mary's Hospital and Health Center": "Mount St. Mary's",
        'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp': 'Jones Memorial',
        'Eastern Niagara Hospital - Lockport Division': 'Eastern Niagara',
        'Roswell Park Cancer Institute': 'Roswell Park',
        'United Memorial Medical Center North Street Campus': 'United Memorial - North',
        'Niagara Falls Memorial Medical Center': 'Niagara Falls Memorial',
        'Sisters of Charity Hospital - St. Joseph Campus': 'Sisters - St.Joseph',
        'Bertrand Chaffee Hospital': 'Bertrand Chaffee',
        'Cuba Memorial Hospital Inc': 'Cuba Memorial',
        'Degraff Memorial Hospital': 'Degraff',
        'United Memorial Medical Center Bank Street Campus': 'United Memorial - Bank',
        'Medina Memorial Hospital': 'Medina Memorial',
        'Westfield Memorial Hospital Inc': 'Westfield Memorial'
}

# %%
df.replace({'Facility Name': hospitals_mapping}, inplace=True)

# %%
df.to_csv('cleaned_health_data.csv', index=False)

# %%
csv_path = "/content/cleaned_health_data.csv"

df_cleaned = pd.read_csv(csv_path)
pd.set_option('display.max_columns', None)
df_cleaned.head(5)
# Out:
#   Hospital County    Facility Name    Age Group Short Zip Code Gender  \
# 0            Erie  Buffalo General  70 or Older            142      F
# 1            Erie  Buffalo General     50 to 69            141      M
# 2            Erie  Buffalo General  70 or Older            147      M
# 3            Erie  Buffalo General     50 to 69            142      F
# 4            Erie  Buffalo General     30 to 49            147      M
#
#                      Race          Ethnicity Length of Stay Type of Admission  \
# 0                   White  Not Span/Hispanic              8         Emergency
# 1              Other Race            Unknown              2            Urgent
# 2                   White  Not Span/Hispanic              1          Elective
# 3  Black/African American  Not Span/Hispanic              6         Emergency
# 4                   White  Not Span/Hispanic              1         Emergency
#
#                  Patient Disposition  Discharge Year CCSR Diagnosis Code  \
# 0  Inpatient Rehabilitation Facility            2018              INJ037
# 1       Home w/ Home Health Services            2018              INJ006
# 2                  Home or Self Care            2018              CIR023
# 3                  Home or Self Care            2018              DIG013
# 4                  Home or Self Care            2018              END012
#
#                           CCSR Diagnosis Description CCSR Procedure Code  \
# 0  COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE...              MST020
# 1  FRACTURE OF THE NECK OF THE FEMUR (HIP), INITI...              MST007
# 2  OCCLUSION OR STENOSIS OF PRECEREBRAL OR CEREBR...              CAR006
# 3                  DIVERTICULOSIS AND DIVERTICULITIS              GIS002
# 4                                    CYSTIC FIBROSIS                 NaN
#
#                 CCSR Procedure Description  APR DRG Code  \
# 0  SUBCUTANEOUS TISSUE AND FASCIA EXCISION           721
# 1                         HIP ARTHROPLASTY           301
# 2      CAROTID ENDARTERECTOMY AND STENTING            24
# 3  COLONOSCOPY AND PROCTOSCOPY WITH BIOPSY           244
# 4                                      NaN           254
#
#                                  APR DRG Description  APR MDC Code  \
# 0  POST-OPERATIVE, POST-TRAUMATIC, OTHER DEVICE I...            18
# 1                              HIP JOINT REPLACEMENT             8
# 2                   EXTRACRANIAL VASCULAR PROCEDURES             1
# 3                    DIVERTICULITIS & DIVERTICULOSIS             6
# 4                   OTHER DIGESTIVE SYSTEM DIAGNOSES             6
#
#                                  APR MDC Description  \
# 0  INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR...
# 1  DISEASES AND DISORDERS OF THE MUSCULOSKELETAL ...
# 2       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM
# 3     DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM
# 4     DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             4                             Extreme
# 1                             2                            Moderate
# 2                             1                               Minor
# 3                             3                               Major
# 4                             2                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0               Extreme                          Medical
# 1                 Minor                         Surgical
# 2                 Minor                         Surgical
# 3              Moderate                          Medical
# 4                 Minor                          Medical
#
#          Payment Typology 1        Payment Typology 2  \
# 0                  Medicare    Blue Cross/Blue Shield
# 1       Miscellaneous/Other  Private Health Insurance
# 2                  Medicare                  Self-Pay
# 3                  Medicare                  Self-Pay
# 4  Private Health Insurance                  Self-Pay
#
#    Emergency Department Indicator  Total Charges  Total Costs  \
# 0                            True       55367.55     20121.21
# 1                           False       48328.30     16943.32
# 2                           False       17052.12      7673.72
# 3                            True       17287.12      9058.50
# 4                            True        6821.06      1987.18
#
#               General_MDC
# 0     Infectious Diseases
# 1  Musculoskeletal System
# 2          Nervous System
# 3        Digestive System
# 4        Digestive System

# %%
unique_APR = df['APR DRG Description'].nunique()
unique_APR
# Out:
# 319

# %%
unique_APR = df['APR DRG Description'].nunique()
unique_APR

# %%
unique_MDC = df['CCSR Diagnosis Description'].nunique()
unique_MDC
# Out:
# 438

# %%
unique_MDC = df['CCSR Diagnosis Description'].unique()
unique_MDC.tolist()
# Out:
# ['COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, INITIAL ENCOUNTER',
#  'FRACTURE OF THE NECK OF THE FEMUR (HIP), INITIAL ENCOUNTER',
#  'OCCLUSION OR STENOSIS OF PRECEREBRAL OR CEREBRAL ARTERIES WITHOUT INFARCTION',
#  'DIVERTICULOSIS AND DIVERTICULITIS',
#  'CYSTIC FIBROSIS',
#  'ACUTE HEMORRHAGIC CEREBROVASCULAR DISEASE',
#  'CONDUCTION DISORDERS',
#  'PERITONITIS AND INTRA-ABDOMINAL ABSCESS',
#  'ASTHMA',
#  'COMPLICATIONS SPECIFIED DURING CHILDBIRTH',
#  'ACUTE BRONCHITIS',
#  'VIRAL INFECTION',
#  'RESPIRATORY FAILURE; INSUFFICIENCY; ARREST',
#  'SEQUELA OF HEMORRHAGIC CEREBROVASCULAR DISEASE',
#  'LIVEBORN',
#  'DIGESTIVE CONGENITAL ANOMALIES',
#  'SEQUELA OF CEREBRAL INFARCTION AND OTHER CEREBROVASCULAR DISEASE',
#  'ACUTE AND UNSPECIFIED RENAL FAILURE',
#  'PARALYSIS (OTHER THAN CEREBRAL PALSY)',
#  'ACUTE MYOCARDIAL INFARCTION',
#  'CORONARY ATHEROSCLEROSIS AND OTHER HEART DISEASE',
#  'FRACTURE OF THE SPINE AND BACK, INITIAL ENCOUNTER',
#  'OBESITY',
#  'NONRHEUMATIC AND UNSPECIFIED VALVE DISORDERS',
#  'HYPERTENSION WITH COMPLICATIONS AND SECONDARY HYPERTENSION',
#  'SEPTICEMIA',
#  'OSTEOARTHRITIS',
#  'OTHER SPECIFIED NERVOUS SYSTEM DISORDERS',
#  'NEONATAL ABSTINENCE SYNDROME',
#  'FRACTURE OF HEAD AND NECK, INITIAL ENCOUNTER',
#  'HEMOLYTIC JAUNDICE AND PERINATAL JAUNDICE',
#  'PROLONGED PREGNANCY',
#  'NEONATAL DIGESTIVE AND FEEDING DISORDERS',
#  'TRANSIENT CEREBRAL ISCHEMIA',
#  'MALPOSITION, DISPROPORTION OR OTHER LABOR COMPLICATIONS',
#  'SKIN AND SUBCUTANEOUS TISSUE INFECTIONS',
#  'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF KIDNEY AND URETERS',
#  'BENIGN NEOPLASMS',
#  'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, INITIAL ENCOUNTER',
#  'PROLAPSE OF FEMALE GENITAL ORGANS',
#  'HYPERTENSION AND HYPERTENSIVE-RELATED CONDITIONS COMPLICATING PREGNANCY; CHILDBIRTH; AND THE PUERPERIUM',
#  'DIABETES OR ABNORMAL GLUCOSE TOLERANCE COMPLICATING PREGNANCY; CHILDBIRTH; OR THE PUERPERIUM',
#  'SPONDYLOPATHIES/SPONDYLOARTHROPATHY (INCLUDING INFECTIVE)',
#  'OSTEOMYELITIS',
#  'OTHER AFTERCARE ENCOUNTER',
#  'UNCOMPLICATED PREGNANCY, DELIVERY OR PUERPERIUM',
#  'OTHER SPECIFIED COMPLICATIONS IN PREGNANCY',
#  'PREVIOUS C-SECTION',
#  'PANCREATIC DISORDERS (EXCLUDING DIABETES)',
#  'BIPOLAR AND RELATED DISORDERS',
#  'PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)',
#  'HEART FAILURE',
#  'TRAUMA- AND STRESSOR-RELATED DISORDERS',
#  'ALCOHOL-RELATED DISORDERS',
#  'HEPATIC FAILURE',
#  'DEPRESSIVE DISORDERS',
#  'DISORDERS OF JAW',
#  'FRACTURE OF THE LOWER LIMB (EXCEPT HIP), INITIAL ENCOUNTER',
#  'NEUROCOGNITIVE DISORDERS',
#  'OPIOID-RELATED DISORDERS',
#  'BILIARY TRACT DISEASE',
#  'CARDIAC DYSRHYTHMIAS',
#  'CHRONIC OBSTRUCTIVE PULMONARY DISEASE AND BRONCHIECTASIS',
#  'NON-HODGKIN LYMPHOMA',
#  'MATERNAL CARE RELATED TO FETAL CONDITIONS',
#  'FLUID AND ELECTROLYTE DISORDERS',
#  'MUSCLE DISORDERS',
#  'DIABETES MELLITUS WITH COMPLICATION',
#  'EARLY OR THREATENED LABOR',
#  'INTESTINAL OBSTRUCTION AND ILEUS',
#  'GASTROINTESTINAL AND BILIARY PERFORATION',
#  'APPENDICITIS AND OTHER APPENDICEAL CONDITIONS',
#  'EPILEPSY; CONVULSIONS',
#  'PRESSURE ULCER OF SKIN',
#  'COMPLICATION OF TRANSPLANTED ORGANS OR TISSUE, INITIAL ENCOUNTER',
#  'ACUTE PULMONARY EMBOLISM',
#  'GASTROINTESTINAL CANCERS - ESOPHAGUS',
#  'MISCELLANEOUS MENTAL AND BEHAVIORAL DISORDERS/CONDITIONS',
#  'URINARY TRACT INFECTIONS',
#  'SEDATIVE-RELATED DISORDERS',
#  'APLASTIC ANEMIA',
#  'GASTROINTESTINAL CANCERS - COLORECTAL',
#  'SCHIZOPHRENIA SPECTRUM AND OTHER PSYCHOTIC DISORDERS',
#  'MULTIPLE SCLEROSIS',
#  'GANGRENE',
#  'CEREBRAL INFARCTION',
#  'CHRONIC RHEUMATIC HEART DISEASE',
#  'AORTIC; PERIPHERAL; AND VISCERAL ARTERY ANEURYSMS',
#  'HYPERPLASIA OF PROSTATE',
#  'OTHER SPECIFIED CONNECTIVE TISSUE DISEASE',
#  'HYPOTENSION',
#  'ACUTE PHLEBITIS; THROMBOPHLEBITIS AND THROMBOEMBOLISM',
#  'ABDOMINAL HERNIA',
#  'SYSTEMIC LUPUS ERYTHEMATOSUS AND CONNECTIVE TISSUE DISORDERS',
#  'PERSONALITY DISORDERS',
#  'SYNCOPE',
#  'POLYHYDRAMNIOS AND OTHER PROBLEMS OF AMNIOTIC CAVITY',
#  'PERIPHERAL AND VISCERAL VASCULAR DISEASE',
#  'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#  'REGIONAL ENTERITIS AND ULCERATIVE COLITIS',
#  'CHRONIC KIDNEY DISEASE',
#  'OTHER SPECIFIED AND UNSPECIFIED DISORDERS OF STOMACH AND DUODENUM',
#  'POSTPROCEDURAL OR POSTOPERATIVE GENITOURINARY SYSTEM COMPLICATION',
#  'ABDOMINAL PAIN AND OTHER DIGESTIVE/ABDOMEN SIGNS AND SYMPTOMS',
#  'NONINFECTIOUS GASTROENTERITIS',
#  'OTHER SPECIFIED AND UNSPECIFIED LIVER DISEASE',
#  'DISRUPTIVE, IMPULSE-CONTROL AND CONDUCT DISORDERS',
#  'ASPIRATION PNEUMONITIS',
#  'STIMULANT-RELATED DISORDERS',
#  'PITUITARY DISORDERS',
#  'OB-RELATED TRAUMA TO PERINEUM AND VULVA',
#  'SUICIDAL IDEATION/ATTEMPT/INTENTIONAL SELF-HARM',
#  'GASTROINTESTINAL HEMORRHAGE',
#  'HEPATITIS',
#  'COAGULATION AND HEMORRHAGIC DISORDERS',
#  'SICKLE CELL TRAIT/ANEMIA',
#  'OTHER SPECIFIED AND UNSPECIFIED GASTROINTESTINAL DISORDERS',
#  'INFLUENZA',
#  'ESOPHAGEAL DISORDERS',
#  'PLEURISY, PLEURAL EFFUSION AND PULMONARY COLLAPSE',
#  'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#  'OTHER SPECIFIED INFLAMMATORY CONDITION OF SKIN',
#  'OTHER SPECIFIED AND UNSPECIFIED SKIN DISORDERS',
#  'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, INITIAL ENCOUNTER',
#  'ENCEPHALITIS',
#  'OTHER SPECIFIED AND UNSPECIFIED MOOD DISORDERS',
#  'INTERNAL ORGAN INJURY, INITIAL ENCOUNTER',
#  'OTHER SPECIFIED INJURY',
#  'ACUTE POSTHEMORRHAGIC ANEMIA',
#  'NEOPLASM-RELATED ENCOUNTERS',
#  'MENTAL AND SUBSTANCE USE DISORDERS IN REMISSION',
#  'POISONING BY DRUGS, INITIAL ENCOUNTER',
#  'NEOPLASMS OF UNSPECIFIED NATURE OR UNCERTAIN BEHAVIOR',
#  'CALCULUS OF URINARY TRACT',
#  'GENERAL SENSATION/PERCEPTION SIGNS AND SYMPTOMS',
#  'ABNORMAL FINDINGS WITHOUT DIAGNOSIS',
#  'HEADACHE; INCLUDING MIGRAINE',
#  'SCOLIOSIS AND OTHER POSTURAL DORSOPATHIC DEFORMITIES',
#  'OTHER SPECIFIED FEMALE GENITAL DISORDERS',
#  'FRACTURE OF THE UPPER LIMB, INITIAL ENCOUNTER',
#  'CANNABIS-RELATED DISORDERS',
#  'MATERNAL CARE RELATED TO DISORDERS OF THE PLACENTA AND PLACENTAL IMPLANTATION',
#  'OSTEOPOROSIS',
#  'NERVOUS SYSTEM CANCERS - BRAIN',
#  'PARKINSON`S DISEASE',
#  'DISEASES OF MIDDLE EAR AND MASTOID (EXCEPT OTITIS MEDIA)',
#  'GASTROINTESTINAL CANCERS - STOMACH',
#  'DISEASES OF WHITE BLOOD CELLS',
#  'CONDITIONS DUE TO NEOPLASM OR THE TREATMENT OF NEOPLASM',
#  'OTHER SPECIFIED AND UNSPECIFIED NUTRITIONAL AND METABOLIC DISORDERS',
#  'GASTRODUODENAL ULCER',
#  'ARTERIAL DISSECTIONS',
#  'FRACTURE OF TORSO, INITIAL ENCOUNTER',
#  'GASTRITIS AND DUODENITIS',
#  'SECONDARY MALIGNANCIES',
#  'RESPIRATORY SIGNS AND SYMPTOMS',
#  'GASTROINTESTINAL CANCERS - GALLBLADDER',
#  'PULMONARY HEART DISEASE',
#  'TENDON AND SYNOVIAL DISORDERS',
#  'INTESTINAL INFECTION',
#  'MALAISE AND FATIGUE',
#  'OTHER GENERAL SIGNS AND SYMPTOMS',
#  'MUSCULOSKELETAL ABSCESS',
#  'NEURODEVELOPMENTAL DISORDERS',
#  'NERVE AND NERVE ROOT DISORDERS',
#  'OTHER SPECIFIED AND UNSPECIFIED ENDOCRINE DISORDERS',
#  'NONSPECIFIC CHEST PAIN',
#  'POSTPROCEDURAL OR POSTOPERATIVE DIGESTIVE SYSTEM COMPLICATION',
#  'ENDOCARDITIS AND ENDOCARDIAL DISEASE',
#  'MUSCULOSKELETAL CONGENITAL CONDITIONS',
#  'OTHER SPECIFIED HEREDITARY AND DEGENERATIVE NERVOUS SYSTEM CONDITIONS',
#  'OTHER SPECIFIED AND UNSPECIFIED LOWER RESPIRATORY DISEASE',
#  'INFLAMMATORY CONDITIONS OF MALE GENITAL ORGANS',
#  'ENCOUNTER FOR ANTINEOPLASTIC THERAPIES',
#  'URINARY SYSTEM CANCERS - KIDNEY',
#  'SUPERFICIAL INJURY; CONTUSION, INITIAL ENCOUNTER',
#  'SARCOMA',
#  'CANCER OF OTHER SITES',
#  'SPRAINS AND STRAINS, INITIAL ENCOUNTER',
#  'RHEUMATOID ARTHRITIS AND RELATED DISEASE',
#  'ASEPTIC NECROSIS AND OSTEONECROSIS',
#  'MALE REPRODUCTIVE SYSTEM CANCERS - PROSTATE',
#  'INFLAMMATORY DISEASES OF FEMALE PELVIC ORGANS',
#  'NUTRITIONAL ANEMIA',
#  'DRUG INDUCED OR TOXIC RELATED CONDITION',
#  'URINARY SYSTEM CANCERS - BLADDER',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - ENDOMETRIUM',
#  'RESPIRATORY CANCERS',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - VULVA',
#  'NONINFECTIOUS HEPATITIS',
#  'CHRONIC PHLEBITIS; THROMBOPHLEBITIS AND THROMBOEMBOLISM',
#  'OPEN WOUNDS OF HEAD AND NECK, INITIAL ENCOUNTER',
#  'STRESS FRACTURE, INITIAL ENCOUNTER',
#  'PNEUMOTHORAX',
#  'NERVOUS SYSTEM SIGNS AND SYMPTOMS',
#  'NERVOUS SYSTEM CONGENITAL ANOMALIES',
#  'HEMORRHAGE AFTER FIRST TRIMESTER',
#  'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF BLADDER AND URETHRA',
#  'NERVOUS SYSTEM PAIN AND PAIN SYNDROMES',
#  'TOXIC EFFECTS, INITIAL ENCOUNTER',
#  'ALLERGIC REACTIONS',
#  'HODGKIN LYMPHOMA',
#  'CARDIAC AND CIRCULATORY CONGENITAL ANOMALIES',
#  'NUTRITIONAL DEFICIENCIES',
#  'BREAST CANCER - ALL OTHER TYPES',
#  'DISEASES OF INNER EAR AND RELATED CONDITIONS',
#  'AORTIC AND PERIPHERAL ARTERIAL EMBOLISM OR THROMBOSIS',
#  'MALTREATMENT/ABUSE',
#  'PERINATAL INFECTIONS',
#  'RESPIRATORY PERINATAL CONDITION',
#  'MESOTHELIOMA',
#  'NAUSEA AND VOMITING',
#  'RESPIRATORY CONGENITAL MALFORMATIONS',
#  'CARDIAC CANCERS',
#  'THYROID DISORDERS',
#  'ENDOCRINE SYSTEM CANCERS - ALL OTHER TYPES',
#  'FRACTURE OF TORSO, SUBSEQUENT ENCOUNTER',
#  'OTHER SPECIFIED AND UNSPECIFIED PERINATAL CONDITIONS',
#  'OTHER SPECIFIED JOINT DISORDERS',
#  'DYSPHAGIA',
#  'POSTTHROMBOTIC SYNDROME AND VENOUS INSUFFICIENCY/HYPERTENSION',
#  'HEMORRHOIDS',
#  'PARASITIC, OTHER SPECIFIED AND UNSPECIFIED INFECTIONS',
#  'OTHER SPECIFIED STATUS',
#  'OTHER AND ILL-DEFINED HEART DISEASE',
#  'PERICARDITIS AND PERICARDIAL DISEASE',
#  'IMMUNITY DISORDERS',
#  'INJURY TO BLOOD VESSELS, INITIAL ENCOUNTER',
#  'NONMALIGNANT BREAST CONDITIONS',
#  'OPEN WOUNDS TO LIMBS, INITIAL ENCOUNTER',
#  'MUSCULOSKELETAL PAIN, NOT LOW BACK PAIN',
#  'OTHER SPECIFIED UPPER RESPIRATORY INFECTIONS',
#  'HEMOLYTIC ANEMIA',
#  'INJURY, SEQUELA',
#  'OTHER SPECIFIED SUBSTANCE-RELATED DISORDERS',
#  'OTHER SPECIFIED AND UNSPECIFIED UPPER RESPIRATORY DISEASE',
#  'CIRCULATORY SIGNS AND SYMPTOMS',
#  'JUVENILE ARTHRITIS',
#  'POLYNEUROPATHIES',
#  'ANXIETY AND FEAR-RELATED DISORDERS',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - OVARY',
#  'POSTPROCEDURAL OR POSTOPERATIVE MUSCULOSKELETAL SYSTEM COMPLICATION',
#  'POSTPROCEDURAL OR POSTOPERATIVE RESPIRATORY SYSTEM COMPLICATION',
#  'LEUKEMIA - CHRONIC MYELOID LEUKEMIA (CML)',
#  'BURN AND CORROSION, INITIAL ENCOUNTER',
#  'MYOCARDITIS AND CARDIOMYOPATHY',
#  'ENDOMETRIOSIS',
#  'CRUSHING INJURY, INITIAL ENCOUNTER',
#  'OTHER AND ILL-DEFINED CEREBROVASCULAR DISEASE',
#  'LOW BACK PAIN',
#  'OTHER SPECIFIED BONE DISEASE AND MUSCULOSKELETAL DEFORMITIES',
#  'HEAD AND NECK CANCERS - THROAT',
#  'HEAD AND NECK CANCERS - LARYNGEAL',
#  'ACUTE AND CHRONIC TONSILLITIS',
#  'FRACTURE OF THE NECK OF THE FEMUR (HIP), SUBSEQUENT ENCOUNTER',
#  'SLEEP WAKE DISORDERS',
#  'POSTPROCEDURAL OR POSTOPERATIVE NERVOUS SYSTEM COMPLICATION',
#  'CONTACT DERMATITIS',
#  'BIRTH TRAUMA',
#  'AMPUTATION OF A LIMB, INITIAL ENCOUNTER',
#  'MATERNAL INTRAUTERINE INFECTION',
#  'DISEASES OF MOUTH; EXCLUDING DENTAL',
#  'OBSTETRIC HISTORY AFFECTING CARE IN PREGNANCY',
#  'GOUT',
#  'BIOMECHANICAL LESIONS',
#  'ENDOCRINE SYSTEM CANCERS - PANCREAS',
#  'BLINDNESS AND VISION DEFECTS',
#  'VESICOURETERAL REFLUX',
#  'INFECTIVE ARTHRITIS',
#  'BACTERIAL INFECTIONS',
#  'BREAST CANCER - DUCTAL CARCINOMA IN SITU (DCIS)',
#  'FEVER',
#  'MALNUTRITION',
#  'CNS ABSCESS',
#  'ENDOCRINE SYSTEM CANCERS - THYROID',
#  'URINARY SYSTEM CANCERS - URETER AND RENAL PELVIS',
#  'LEUKEMIA - ACUTE MYELOID LEUKEMIA (AML)',
#  'FEEDING AND EATING DISORDERS',
#  'MYOPATHIES',
#  'RETINAL AND VITREOUS CONDITIONS',
#  'COMPLICATIONS SPECIFIED DURING THE PUERPERIUM',
#  'OTHER SPECIFIED DISEASES OF VEINS AND LYMPHATICS',
#  'LEUKEMIA - ALL OTHER TYPES',
#  'POSTPROCEDURAL OR POSTOPERATIVE CIRCULATORY SYSTEM COMPLICATION',
#  'GENITOURINARY CONGENITAL ANOMALIES',
#  'SHORT GESTATION; LOW BIRTH WEIGHT; AND FETAL GROWTH RETARDATION',
#  'OTHER SPECIFIED AND UNSPECIFIED HEMATOLOGIC CONDITIONS',
#  'INJURY TO NERVES, MUSCLES AND TENDONS, INITIAL ENCOUNTER',
#  'NON-PRESSURE ULCER OF SKIN',
#  'NEURO-OPHTHALMOLOGY',
#  'PATHOLOGICAL FRACTURE, INITIAL ENCOUNTER',
#  'MULTIPLE GESTATION',
#  'ACQUIRED FOOT DEFORMITIES',
#  'DISORDERS OF TEETH AND GINGIVA',
#  'OCULOFACIAL PLASTICS AND ORBITAL CONDITIONS',
#  'OTITIS MEDIA',
#  'HEAD AND NECK CANCERS - LIP AND ORAL CAVITY',
#  'OPEN WOUNDS OF TRUNK, INITIAL ENCOUNTER',
#  'NEPHRITIS; NEPHROSIS; RENAL SCLEROSIS',
#  'MULTIPLE MYELOMA',
#  'HIV INFECTION',
#  'GASTROINTESTINAL CANCERS - ANUS',
#  'ESSENTIAL HYPERTENSION',
#  'MOLAR PREGNANCY AND OTHER ABNORMAL PRODUCTS OF CONCEPTION',
#  'ANAL AND RECTAL CONDITIONS',
#  'MENINGITIS',
#  'SKIN CANCERS - BASAL CELL CARCINOMA',
#  'POSTPROCEDURAL OR POSTOPERATIVE SKIN COMPLICATION',
#  'NEUROGENIC/NEUROPATHIC ARTHROPATHY',
#  'BENIGN OVARIAN CYST',
#  'EFFECT OF FOREIGN BODY ENTERING OPENING, INITIAL ENCOUNTER',
#  'CARDIAC ARREST AND VENTRICULAR FIBRILLATION',
#  'MYELODYSPLASTIC SYNDROME (MDS)',
#  'COMA; STUPOR; AND BRAIN DAMAGE',
#  'POISONING BY DRUGS, SUBSEQUENT ENCOUNTER',
#  'SKIN CANCERS - ALL OTHER TYPES',
#  'TRAUMATIC ARTHROPATHY',
#  'OBSESSIVE-COMPULSIVE AND RELATED DISORDERS',
#  'LEUKEMIA - CHRONIC LYMPHOCYTIC LEUKEMIA (CLL)',
#  'GASTROINTESTINAL CANCERS - LIVER',
#  'SPINAL CORD INJURY (SCI), INITIAL ENCOUNTER',
#  'HEAD AND NECK CANCERS - NASOPHARYNGEAL',
#  'CLEFT LIP OR PALATE',
#  'BONE CANCER',
#  'OTHER SPECIFIED AND UNSPECIFIED DISORDERS OF THE EAR',
#  'SOMATIC DISORDERS',
#  'FRACTURE OF LOWER LIMB (EXCEPT HIP), SUBSEQUENT ENCOUNTER',
#  'MENSTRUAL DISORDERS',
#  'INTERNAL ORGAN INJURY, SUBSEQUENT ENCOUNTER',
#  'MENOPAUSAL DISORDERS',
#  'MALIGNANT NEUROENDOCRINE TUMORS',
#  'BURNS AND CORROSION, SUBSEQUENT ENCOUNTER',
#  'SINUSITIS',
#  'FRACTURE OF THE UPPER LIMB, SUBSEQUENT ENCOUNTER',
#  'OTHER SPECIFIED AND UNSPECIFIED CIRCULATORY DISEASE',
#  'GASTROINTESTINAL CANCERS - ALL OTHER TYPES',
#  'SKIN CANCERS - MELANOMA',
#  'MATERNAL CARE FOR ABNORMALITY OF PELVIC ORGANS',
#  'GENITOURINARY SIGNS AND SYMPTOMS',
#  'OTHER UNSPECIFIED INJURY',
#  'RESPIRATORY DISTRESS SYNDROME',
#  'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, SUBSEQUENT ENCOUNTER',
#  'HEMATURIA',
#  'ENDOCRINE SYSTEM CANCERS - ADRENOCORTICAL',
#  'FRACTURE OF THE SPINE AND BACK, SUBSEQUENT ENCOUNTER',
#  'SPINAL CORD INJURY (SCI), SUBSEQUENT ENCOUNTER',
#  'GASTROINTESTINAL CANCERS - BILE DUCT',
#  'MALE REPRODUCTIVE SYSTEM CANCERS - PENIS',
#  'GASTROINTESTINAL CANCERS - PERITONEUM',
#  'NEONATAL CEREBRAL DISORDERS',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - CERVIX',
#  'IMMUNE-MEDIATED/REACTIVE ARTHROPATHIES',
#  'POSTPROCEDURAL OR POSTOPERATIVE ENDOCRINE OR METABOLIC COMPLICATION',
#  'EFFECT OF OTHER EXTERNAL CAUSES, INITIAL ENCOUNTER',
#  'GASTROINTESTINAL CANCERS - SMALL INTESTINE',
#  'ENDOCRINE SYSTEM CANCERS - PITUITARY GLAND',
#  'DISLOCATIONS, INITIAL ENCOUNTER',
#  'MALIGNANT NEOPLASM, UNSPECIFIED',
#  'SEXUALLY TRANSMITTED INFECTIONS (EXCLUDING HIV AND HEPATITIS)',
#  'HALLUCINOGEN-RELATED DISORDERS',
#  'HEAD AND NECK CANCERS - HYPOPHARYNGEAL',
#  'LEUKEMIA - ACUTE LYMPHOBLASTIC LEUKEMIA (ALL)',
#  'VARICOSE VEINS OF LOWER EXTREMITY',
#  'ENCOUNTER FOR OBSERVATION AND EXAMINATION FOR CONDITIONS RULED OUT (EXCLUDES INFECTIOUS DISEASE, NEOPLASM, MENTAL DISORDERS)',
#  'FRACTURE OF HEAD AND NECK, SUBSEQUENT ENCOUNTER',
#  'URINARY INCONTINENCE',
#  'OTHER SPECIFIED EYE DISORDERS',
#  'ACQUIRED DEFORMITIES (EXCLUDING FOOT)',
#  'OTHER SPECIFIED MALE GENITAL DISORDERS',
#  'HEAD AND NECK CANCERS - ALL OTHER TYPES',
#  'HEAD AND NECK CANCERS - SALIVARY GLAND',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - UTERUS',
#  'STRESS FRACTURE, SUBSEQUENT ENCOUNTER',
#  'DIABETES MELLITUS WITHOUT COMPLICATION',
#  'MEDIASTINAL DISORDERS',
#  'CATARACT AND OTHER LENS DISORDERS',
#  'PATHOLOGICAL FRACTURE, SUBSEQUENT ENCOUNTER',
#  'SHOCK',
#  'ENCOUNTER FOR PROPHYLACTIC OR OTHER PROCEDURES',
#  'TUBERCULOSIS',
#  'SKIN/SUBCUTANEOUS SIGNS AND SYMPTOMS',
#  'SEQUELA OF SPECIFIED NERVOUS SYSTEM CONDITIONS',
#  'DISORDERS OF LIPID METABOLISM',
#  'CORNEA AND EXTERNAL DISEASE',
#  'SKIN CANCERS - SQUAMOUS CELL CARCINOMA',
#  'UVEITIS AND OCULAR INFLAMMATION',
#  'HEAD AND NECK CANCERS - TONSILS',
#  'FOODBORNE INTOXICATIONS',
#  'ATYPICAL FRACTURE, INITIAL ENCOUNTER',
#  'ACUTE RHEUMATIC HEART DISEASE',
#  'SUPERFICIAL INJURY; CONTUSION, SUBSEQUENT ENCOUNTER',
#  'NEWBORN AFFECTED BY MATERNAL CONDITIONS OR COMPLICATIONS OF LABOR/DELIVERY',
#  'OTHER UNSPECIFIED INJURIES, SUBSEQUENT ENCOUNTER',
#  'OTHER SPECIFIED AND UNSPECIFIED CONGENITAL ANOMALIES',
#  'SUICIDE ATTEMPT/INTENTIONAL SELF-HARM; SUBSEQUENT ENCOUNTER',
#  'HEARING LOSS',
#  'CEREBRAL PALSY',
#  'HEMORRHAGIC AND HEMATOLOGIC DISORDERS OF NEWBORN',
#  'FEMALE INFERTILITY',
#  'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, SUBSEQUENT ENCOUNTER',
#  'OTHER SPECIFIED CNS INFECTION AND POLIOMYELITIS',
#  'COMPLICATIONS OF ACUTE MYOCARDIAL INFARCTION',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - ALL OTHER TYPES',
#  'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, SUBSEQUENT ENCOUNTER',
#  'IMPLANT, DEVICE OR GRAFT RELATED ENCOUNTER',
#  'GLAUCOMA',
#  'OPEN WOUNDS OF HEAD AND NECK, SUBSEQUENT ENCOUNTER',
#  'HEAD AND NECK CANCERS - PHARYNGEAL',
#  'MALE REPRODUCTIVE SYSTEM CANCERS - TESTIS',
#  'FUNGAL INFECTIONS',
#  'URINARY SYSTEM CANCERS - ALL OTHER TYPES',
#  'LUNG DISEASE DUE TO EXTERNAL AGENTS',
#  'ADVERSE EFFECTS OF DRUGS AND MEDICAMENTS, INITIAL ENCOUNTER',
#  'AUTOINFLAMMATORY SYNDROMES',
#  'NERVOUS SYSTEM CANCERS - ALL OTHER TYPES',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - FALLOPIAN TUBE',
#  'SPRAINS AND STRAINS, SUBSEQUENT ENCOUNTER',
#  'OTHER SPECIFIED INJURY, SUBSEQUENT ENCOUNTER',
#  'EARLY, FIRST OR UNSPECIFIED TRIMESTER HEMORRHAGE',
#  'STRABISMUS',
#  'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, SUBSEQUENT ENCOUNTER',
#  'LEUKEMIA - HAIRY CELL',
#  'ENDOCRINE SYSTEM CANCERS - THYMUS',
#  'POSTPROCEDURAL OR POSTOPERATIVE EYE COMPLICATION',
#  'INHALANT-RELATED DISORDERS',
#  'ERECTILE DYSFUNCTION',
#  nan,
#  'OPEN WOUNDS TO LIMBS, SUBSEQUENT ENCOUNTER',
#  'SYMPTOMS OF MENTAL AND SUBSTANCE USE CONDITIONS',
#  'CONGENITAL MALFORMATIONS OF EYE, EAR, FACE, NECK',
#  'ENDOCRINE SYSTEM CANCERS - PARATHYROID',
#  'NEONATAL ACIDEMIA AND HYPOXIA',
#  'CRYSTAL ARTHROPATHIES (EXCLUDING GOUT)',
#  'EXPOSURE, ENCOUNTERS, SCREENING OR CONTACT WITH INFECTIOUS DISEASE',
#  'URINARY SYSTEM CANCERS - URETHRA',
#  'OPEN WOUNDS OF TRUNK, SUBSEQUENT ENCOUNTER',
#  'DISLOCATIONS, SUBSEQUENT ENCOUNTER',
#  'POSTPROCEDURAL OR POSTOPERATIVE COMPLICATIONS OF THE SPLEEN',
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - VAGINA']
